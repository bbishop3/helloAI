# %% [markdown]
# <a href="https://colab.research.google.com/github/bbishop3/helloAI/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GOAL: use softmax to demonstrate that input images that are hard to classify produce an even 10-split of outputs

# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
#!git clone "https://github.com/kartoone/nn3"
#!git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd nn3/src
# Out:
# /content/nn3/src

# %%
from network2 import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[-1.6287815 ],
#        [-1.25428331],
#        [-1.22253852],
#        [-0.44962404],
#        [-0.65815312],
#        [ 0.01584235],
#        [-0.84821203],
#        [ 0.92880956],
#        [ 2.27610559],
#        [-0.01720339],
#        [ 0.06717447],
#        [-1.04662771],
#        [ 0.94763013],
#        [-0.76773731],
#        [ 1.07085761],
#        [ 1.78343356],
#        [-0.25740219],
#        [ 1.42082036],
#        [ 0.95642769],
#        [ 1.91149555],
#        [-0.638779  ],
#        [ 1.02563348],
#        [ 1.11446364],
#        [-1.85751265],
#        [-0.47021046],
#        [ 1.31737101],
#        [ 0.88512489],
#        [-2.4969484 ],
#        [-0.00440143],
#        [-1.75081633]]), array([[-1.49411126],
#        [ 0.24593019],
#        [-0.36627385],
#        [ 1.07880259],
#        [ 2.31419112],
#        [-1.17968837],
#        [ 0.23916211],
#        [ 1.00537255],
#        [ 1.48940287],
#        [-0.75671182]])]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
import numpy as np

# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti

# %%
  from network import Network
  import mnist_loader
  import time

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = [[784,15,10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], [784, 30, 30, 10], [784, 100, 100, 10] ] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
  training_times = []
  accuracies = []
  for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:100], 30, 10, 3.0, test_data=test_data[0:100]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net)
    import matplotlib.pyplot as plt
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# repeat the above IN DIFFERENT CELLS (don't do it all in one cell, you will thank me later) for all the structural configurations
# Out:
# [784, 15, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...11 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.05s...measuring accuracy...14 / 100 in 0.0s
# Epoch 2: starting...training completed in 0.01s...measuring accuracy...16 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...16 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.01s...measuring accuracy...24 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.01s...measuring accuracy...26 / 100 in 0.0s
# Epoch 6: starting...training completed in 0.01s...measuring accuracy...28 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...31 / 100 in 0.0s
# Epoch 8: starting...training completed in 0.01s...measuring accuracy...29 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.01s...measuring accuracy...31 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.01s...measuring accuracy...37 / 100 in 0.0s
# Epoch 11: starting...training completed in 0.01s...measuring accuracy...36 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.01s...measuring accuracy...34 / 100 in 0.0s
# Epoch 13: starting...training completed in 0.01s...measuring accuracy...37 / 100 in 0.0s
# Epoch 14: starting...training completed in 0.01s...measuring accuracy...36 / 100 in 0.0s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 16: starting...training completed in 0.01s...measuring accuracy...41 / 100 in 0.0s
# Epoch 17: starting...training completed in 0.03s...measuring accuracy...42 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.01s...measuring accuracy...39 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.01s...measuring accuracy...42 / 100 in 0.0s
# Epoch 20: starting...training completed in 0.01s...measuring accuracy...42 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.01s...measuring accuracy...41 / 100 in 0.0s
# Epoch 22: starting...training completed in 0.01s...measuring accuracy...42 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.0s
# Epoch 24: starting...training completed in 0.01s...measuring accuracy...42 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.01s...measuring accuracy...41 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.01s...measuring accuracy...41 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 28: starting...training completed in 0.01s...measuring accuracy...45 / 100 in 0.0s
# Epoch 29: starting...training completed in 0.01s...measuring accuracy...44 / 100 in 0.0s
# 0.6956193447113037
# 0.024618986193291878
# 99
# [784, 30, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...16 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...16 / 100 in 0.0s
# Epoch 2: starting...training completed in 0.03s...measuring accuracy...20 / 100 in 0.0s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...21 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...20 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.02s...measuring accuracy...21 / 100 in 0.0s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.03s...measuring accuracy...24 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.03s...measuring accuracy...27 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...29 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...31 / 100 in 0.0s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...32 / 100 in 0.0s
# Epoch 12: starting...training completed in 0.02s...measuring accuracy...33 / 100 in 0.0s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.0s
# Epoch 14: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.02s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.0s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 17: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.02s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.0s
# Epoch 20: starting...training completed in 0.03s...measuring accuracy...43 / 100 in 0.0s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.03s...measuring accuracy...45 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.0s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.0s
# Epoch 29: starting...training completed in 0.03s...measuring accuracy...45 / 100 in 0.0s
# 0.8763754367828369
# 0.022123893027934084
# 36
# [784, 100, 10]
# Epoch 0: starting...training completed in 0.07s...measuring accuracy...14 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.05s...measuring accuracy...27 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.04s...measuring accuracy...24 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.05s...measuring accuracy...29 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.05s...measuring accuracy...32 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.05s...measuring accuracy...28 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.04s...measuring accuracy...32 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.06s...measuring accuracy...29 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.07s...measuring accuracy...31 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.06s...measuring accuracy...30 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.04s...measuring accuracy...35 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.06s...measuring accuracy...34 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.05s...measuring accuracy...35 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.04s...measuring accuracy...35 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.04s...measuring accuracy...35 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.05s...measuring accuracy...36 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.06s...measuring accuracy...36 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.04s...measuring accuracy...37 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.05s...measuring accuracy...37 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.06s...measuring accuracy...43 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.05s...measuring accuracy...44 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...44 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.05s...measuring accuracy...44 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.05s...measuring accuracy...44 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.05s...measuring accuracy...45 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.08s...measuring accuracy...46 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.05s...measuring accuracy...46 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.06s...measuring accuracy...45 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.04s...measuring accuracy...45 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.05s...measuring accuracy...44 / 100 in 0.01s
# 1.821958303451538
# 0.006494453742557282
# 61
# [784, 15, 15, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...7 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...10 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...12 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.03s...measuring accuracy...19 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...18 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.02s...measuring accuracy...20 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...24 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.03s...measuring accuracy...20 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...24 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...26 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.03s...measuring accuracy...40 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.03s...measuring accuracy...43 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.03s...measuring accuracy...45 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...46 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...50 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.02s...measuring accuracy...51 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...50 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...52 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.03s...measuring accuracy...49 / 100 in 0.01s
# 0.8770265579223633
# 0.13655570395322125
# 38
# [784, 30, 30, 10]
# Epoch 0: starting...training completed in 0.05s...measuring accuracy...14 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...20 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.03s...measuring accuracy...21 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.03s...measuring accuracy...21 / 100 in 0.02s
# Epoch 4: starting...training completed in 0.03s...measuring accuracy...27 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.03s...measuring accuracy...27 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.03s...measuring accuracy...31 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...28 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.03s...measuring accuracy...30 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...31 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...35 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.04s...measuring accuracy...34 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.03s...measuring accuracy...38 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.05s...measuring accuracy...39 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.02s
# Epoch 16: starting...training completed in 0.03s...measuring accuracy...38 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.04s...measuring accuracy...39 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.03s...measuring accuracy...40 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.04s...measuring accuracy...42 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.03s...measuring accuracy...38 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...42 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.03s...measuring accuracy...43 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.03s...measuring accuracy...44 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.03s...measuring accuracy...43 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.03s...measuring accuracy...41 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.03s...measuring accuracy...46 / 100 in 0.01s
# 1.1826345920562744
# 0.0527081891412426
# 70
# [784, 100, 100, 10]
# Epoch 0: starting...training completed in 0.06s...measuring accuracy...11 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.06s...measuring accuracy...11 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.08s...measuring accuracy...13 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.07s...measuring accuracy...4 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.06s...measuring accuracy...9 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.07s...measuring accuracy...11 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.06s...measuring accuracy...10 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.07s...measuring accuracy...11 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.07s...measuring accuracy...8 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.06s...measuring accuracy...14 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.07s...measuring accuracy...16 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.06s...measuring accuracy...19 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.06s...measuring accuracy...17 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.07s...measuring accuracy...21 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.06s...measuring accuracy...23 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.05s...measuring accuracy...23 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.09s...measuring accuracy...26 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.06s...measuring accuracy...25 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.05s...measuring accuracy...25 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.07s...measuring accuracy...28 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.06s...measuring accuracy...30 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.05s...measuring accuracy...32 / 100 in 0.03s
# Epoch 22: starting...training completed in 0.08s...measuring accuracy...29 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.06s...measuring accuracy...33 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.05s...measuring accuracy...33 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.06s...measuring accuracy...33 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.06s...measuring accuracy...31 / 100 in 0.02s
# Epoch 27: starting...training completed in 0.07s...measuring accuracy...32 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.05s...measuring accuracy...32 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.06s...measuring accuracy...36 / 100 in 0.02s
# 2.2280189990997314
# 0.006209874069881413
# 58

# %%
print(configs)
print(training_times)
print(accuracies)
# Out:
# [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], [784, 30, 30, 10], [784, 100, 100, 10]]
# [0.6956193447113037, 0.8763754367828369, 1.821958303451538, 0.8770265579223633, 1.1826345920562744, 2.2280189990997314]
# [44, 45, 44, 49, 46, 36]

# %%
  from network2 import Network
  from network2 import QuadraticCost
  import mnist_loader
  import time
  import matplotlib.pyplot as plt

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = []
  for epochs in [15, 30, 45, 100]:
    for batchsize in [5, 10, 20, 100]:
      for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0]:
        configs.append([epochs, batchsize, learningrate])

  # only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
  training_data = training_data[0:100]
  test_data = test_data[0:100]

  training_times = []
  accuracies = []  
  # note that this will be a GIANT list of training times for each config plus the two cost functions. [time1, time2, time3, time4] ... 
  #  time1 and time2 are both associated with the single hidden layer network and differ in the cost function (time1 - crossentropy, time2-quadratic)
  #  time3 and time4 are both associated with the dual hidden layer network and differ in the cost function (time3 - crossentropy, time4-quadratic)
  # NOTE: once you are happy with the results ... remove the 0:1000 and use the complete training data
  for config in configs:
    print(config, "single hidden layer plus cross-entropy")
    start = time.time()
    net1 = Network([784,15,10]) # cross-entropy cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "single hidden layer plus quadratic")
    start = time.time()
    net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

  

    # repeat for the two layer network
    print(config, "dual hidden layers plus cross-entropy")
    start = time.time()
    net2 = Network([784,30,15,10])
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "dual hidden layers plus quadratic")
    start = time.time()
    net2 = Network([784,30,15, 10],cost=QuadraticCost)
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [15, 5, 0.1] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.18
# Epoch 1 training complete
# 1,0.32
# Epoch 2 training complete
# 2,0.48
# Epoch 3 training complete
# 3,0.42
# Epoch 4 training complete
# 4,0.49
# Epoch 5 training complete
# 5,0.55
# Epoch 6 training complete
# 6,0.58
# Epoch 7 training complete
# 7,0.58
# Epoch 8 training complete
# 8,0.62
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.64
# Epoch 14 training complete
# 14,0.67
# 0.3867619037628174
# 0.10737063086640469
# 11
# [15, 5, 0.1] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.24
# Epoch 2 training complete
# 2,0.27
# Epoch 3 training complete
# 3,0.27
# Epoch 4 training complete
# 4,0.27
# Epoch 5 training complete
# 5,0.28
# Epoch 6 training complete
# 6,0.25
# Epoch 7 training complete
# 7,0.27
# Epoch 8 training complete
# 8,0.27
# Epoch 9 training complete
# 9,0.27
# Epoch 10 training complete
# 10,0.27
# Epoch 11 training complete
# 11,0.27
# Epoch 12 training complete
# 12,0.27
# Epoch 13 training complete
# 13,0.28
# Epoch 14 training complete
# 14,0.27
# 0.3810408115386963
# 0.13276584791628326
# 79
# [15, 5, 0.1] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.17
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.13
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.26
# Epoch 7 training complete
# 7,0.24
# Epoch 8 training complete
# 8,0.12
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.22
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.32
# Epoch 14 training complete
# 14,0.3
# 0.6729838848114014
# 0.13871587383835082
# 87
# [15, 5, 0.1] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.07
# Epoch 1 training complete
# 1,0.07
# Epoch 2 training complete
# 2,0.22
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.17
# Epoch 5 training complete
# 5,0.16
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.615624189376831
# 0.1283785121527517
# 95
# [15, 5, 0.5] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.13
# Epoch 1 training complete
# 1,0.47
# Epoch 2 training complete
# 2,0.47
# Epoch 3 training complete
# 3,0.6
# Epoch 4 training complete
# 4,0.63
# Epoch 5 training complete
# 5,0.65
# Epoch 6 training complete
# 6,0.64
# Epoch 7 training complete
# 7,0.67
# Epoch 8 training complete
# 8,0.65
# Epoch 9 training complete
# 9,0.69
# Epoch 10 training complete
# 10,0.69
# Epoch 11 training complete
# 11,0.7
# Epoch 12 training complete
# 12,0.7
# Epoch 13 training complete
# 13,0.7
# Epoch 14 training complete
# 14,0.68
# 0.36014342308044434
# 0.1308243426453375
# 34
# [15, 5, 0.5] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.31
# Epoch 1 training complete
# 1,0.37
# Epoch 2 training complete
# 2,0.24
# Epoch 3 training complete
# 3,0.44
# Epoch 4 training complete
# 4,0.44
# Epoch 5 training complete
# 5,0.48
# Epoch 6 training complete
# 6,0.57
# Epoch 7 training complete
# 7,0.56
# Epoch 8 training complete
# 8,0.58
# Epoch 9 training complete
# 9,0.63
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.64
# Epoch 12 training complete
# 12,0.65
# Epoch 13 training complete
# 13,0.64
# Epoch 14 training complete
# 14,0.64
# 0.42762112617492676
# 0.1433647799171514
# 11
# [15, 5, 0.5] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.21
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.43
# Epoch 4 training complete
# 4,0.33
# Epoch 5 training complete
# 5,0.41
# Epoch 6 training complete
# 6,0.46
# Epoch 7 training complete
# 7,0.55
# Epoch 8 training complete
# 8,0.54
# Epoch 9 training complete
# 9,0.63
# Epoch 10 training complete
# 10,0.68
# Epoch 11 training complete
# 11,0.61
# Epoch 12 training complete
# 12,0.62
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.67
# 0.5895664691925049
# 0.08609455139654659
# 11
# [15, 5, 0.5] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.19
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.13
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.22
# 0.646169900894165
# 0.12492338636622688
# 32
# [15, 5, 1.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.32
# Epoch 1 training complete
# 1,0.49
# Epoch 2 training complete
# 2,0.52
# Epoch 3 training complete
# 3,0.54
# Epoch 4 training complete
# 4,0.61
# Epoch 5 training complete
# 5,0.71
# Epoch 6 training complete
# 6,0.7
# Epoch 7 training complete
# 7,0.68
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.69
# Epoch 10 training complete
# 10,0.68
# Epoch 11 training complete
# 11,0.69
# Epoch 12 training complete
# 12,0.69
# Epoch 13 training complete
# 13,0.7
# Epoch 14 training complete
# 14,0.7
# 0.39388298988342285
# 0.07030475411908192
# 84
# [15, 5, 1.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.22
# Epoch 2 training complete
# 2,0.22
# Epoch 3 training complete
# 3,0.41
# Epoch 4 training complete
# 4,0.46
# Epoch 5 training complete
# 5,0.53
# Epoch 6 training complete
# 6,0.68
# Epoch 7 training complete
# 7,0.66
# Epoch 8 training complete
# 8,0.66
# Epoch 9 training complete
# 9,0.73
# Epoch 10 training complete
# 10,0.69
# Epoch 11 training complete
# 11,0.7
# Epoch 12 training complete
# 12,0.72
# Epoch 13 training complete
# 13,0.69
# Epoch 14 training complete
# 14,0.7
# 0.3952805995941162
# 0.20723476099160648
# 66
# [15, 5, 1.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.23
# Epoch 2 training complete
# 2,0.26
# Epoch 3 training complete
# 3,0.5
# Epoch 4 training complete
# 4,0.44
# Epoch 5 training complete
# 5,0.6
# Epoch 6 training complete
# 6,0.54
# Epoch 7 training complete
# 7,0.6
# Epoch 8 training complete
# 8,0.6
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.6
# Epoch 11 training complete
# 11,0.61
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.68
# Epoch 14 training complete
# 14,0.67
# 0.6532852649688721
# 0.14155778773748035
# 65
# [15, 5, 1.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.2
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.19
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.23
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.2
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.21
# Epoch 14 training complete
# 14,0.22
# 0.6883563995361328
# 0.14245627724261184
# 42
# [15, 5, 3.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.17
# Epoch 1 training complete
# 1,0.29
# Epoch 2 training complete
# 2,0.4
# Epoch 3 training complete
# 3,0.39
# Epoch 4 training complete
# 4,0.49
# Epoch 5 training complete
# 5,0.25
# Epoch 6 training complete
# 6,0.5
# Epoch 7 training complete
# 7,0.34
# Epoch 8 training complete
# 8,0.49
# Epoch 9 training complete
# 9,0.48
# Epoch 10 training complete
# 10,0.47
# Epoch 11 training complete
# 11,0.6
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.57
# Epoch 14 training complete
# 14,0.64
# 0.37561893463134766
# 0.10699097972914319
# 7
# [15, 5, 3.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.48
# Epoch 2 training complete
# 2,0.56
# Epoch 3 training complete
# 3,0.62
# Epoch 4 training complete
# 4,0.61
# Epoch 5 training complete
# 5,0.64
# Epoch 6 training complete
# 6,0.65
# Epoch 7 training complete
# 7,0.66
# Epoch 8 training complete
# 8,0.7
# Epoch 9 training complete
# 9,0.66
# Epoch 10 training complete
# 10,0.7
# Epoch 11 training complete
# 11,0.64
# Epoch 12 training complete
# 12,0.68
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.68
# 0.8390884399414062
# 0.20390399266858886
# 11
# [15, 5, 3.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.34
# Epoch 5 training complete
# 5,0.38
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.42
# Epoch 8 training complete
# 8,0.45
# Epoch 9 training complete
# 9,0.17
# Epoch 10 training complete
# 10,0.32
# Epoch 11 training complete
# 11,0.45
# Epoch 12 training complete
# 12,0.38
# Epoch 13 training complete
# 13,0.57
# Epoch 14 training complete
# 14,0.49
# 1.9626250267028809
# 0.11001850651299906
# 66
# [15, 5, 3.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.24
# Epoch 4 training complete
# 4,0.24
# Epoch 5 training complete
# 5,0.28
# Epoch 6 training complete
# 6,0.43
# Epoch 7 training complete
# 7,0.49
# Epoch 8 training complete
# 8,0.54
# Epoch 9 training complete
# 9,0.54
# Epoch 10 training complete
# 10,0.58
# Epoch 11 training complete
# 11,0.5
# Epoch 12 training complete
# 12,0.58
# Epoch 13 training complete
# 13,0.65
# Epoch 14 training complete
# 14,0.6
# 0.6444945335388184
# 0.11434277248256522
# 63
# [15, 5, 5.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.15
# Epoch 6 training complete
# 6,0.27
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.23
# Epoch 9 training complete
# 9,0.23
# Epoch 10 training complete
# 10,0.22
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.09
# Epoch 13 training complete
# 13,0.15
# Epoch 14 training complete
# 14,0.29
# 0.3557562828063965
# 0.45629330065010154
# 2
# [15, 5, 5.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.28
# Epoch 1 training complete
# 1,0.4
# Epoch 2 training complete
# 2,0.53
# Epoch 3 training complete
# 3,0.46
# Epoch 4 training complete
# 4,0.61
# Epoch 5 training complete
# 5,0.72
# Epoch 6 training complete
# 6,0.71
# Epoch 7 training complete
# 7,0.66
# Epoch 8 training complete
# 8,0.68
# Epoch 9 training complete
# 9,0.67
# Epoch 10 training complete
# 10,0.71
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.7
# Epoch 13 training complete
# 13,0.69
# Epoch 14 training complete
# 14,0.72
# 0.4145991802215576
# 0.1311641404605065
# 34
# [15, 5, 5.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.02
# Epoch 12 training complete
# 12,0.11
# Epoch 13 training complete
# 13,0.11
# Epoch 14 training complete
# 14,0.14
# 0.6299855709075928
# 0.19954260047641997
# 56
# [15, 5, 5.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.02
# Epoch 2 training complete
# 2,0.22
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.25
# Epoch 5 training complete
# 5,0.38
# Epoch 6 training complete
# 6,0.43
# Epoch 7 training complete
# 7,0.55
# Epoch 8 training complete
# 8,0.46
# Epoch 9 training complete
# 9,0.66
# Epoch 10 training complete
# 10,0.64
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.61
# Epoch 14 training complete
# 14,0.64
# 0.681779146194458
# 0.0836731048484608
# 43
# [15, 10, 0.1] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.2
# Epoch 2 training complete
# 2,0.34
# Epoch 3 training complete
# 3,0.34
# Epoch 4 training complete
# 4,0.44
# Epoch 5 training complete
# 5,0.48
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.49
# Epoch 8 training complete
# 8,0.48
# Epoch 9 training complete
# 9,0.51
# Epoch 10 training complete
# 10,0.52
# Epoch 11 training complete
# 11,0.52
# Epoch 12 training complete
# 12,0.52
# Epoch 13 training complete
# 13,0.53
# Epoch 14 training complete
# 14,0.54
# 0.4007141590118408
# 0.12257453070263737
# 66
# [15, 10, 0.1] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.07
# Epoch 1 training complete
# 1,0.07
# Epoch 2 training complete
# 2,0.07
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.13
# Epoch 5 training complete
# 5,0.16
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.24
# Epoch 8 training complete
# 8,0.28
# Epoch 9 training complete
# 9,0.28
# Epoch 10 training complete
# 10,0.28
# Epoch 11 training complete
# 11,0.29
# Epoch 12 training complete
# 12,0.3
# Epoch 13 training complete
# 13,0.3
# Epoch 14 training complete
# 14,0.31
# 0.40645909309387207
# 0.12752416985279622
# 25
# [15, 10, 0.1] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.16
# Epoch 9 training complete
# 9,0.21
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.15
# Epoch 14 training complete
# 14,0.22
# 0.5864300727844238
# 0.1304577697496191
# 20
# [15, 10, 0.1] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.02
# Epoch 2 training complete
# 2,0.02
# Epoch 3 training complete
# 3,0.02
# Epoch 4 training complete
# 4,0.02
# Epoch 5 training complete
# 5,0.02
# Epoch 6 training complete
# 6,0.04
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.08
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.08
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.08
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.08
# 0.686150312423706
# 0.13739934298578388
# 79
# [15, 10, 0.5] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.45
# Epoch 2 training complete
# 2,0.4
# Epoch 3 training complete
# 3,0.51
# Epoch 4 training complete
# 4,0.56
# Epoch 5 training complete
# 5,0.59
# Epoch 6 training complete
# 6,0.67
# Epoch 7 training complete
# 7,0.66
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.69
# Epoch 10 training complete
# 10,0.69
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.74
# 0.3982045650482178
# 0.10798669575331668
# 84
# [15, 10, 0.5] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.12
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.18
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.26
# Epoch 5 training complete
# 5,0.27
# Epoch 6 training complete
# 6,0.29
# Epoch 7 training complete
# 7,0.31
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.37
# Epoch 10 training complete
# 10,0.4
# Epoch 11 training complete
# 11,0.45
# Epoch 12 training complete
# 12,0.51
# Epoch 13 training complete
# 13,0.52
# Epoch 14 training complete
# 14,0.53
# 0.3936729431152344
# 0.16658998124840751
# 95
# [15, 10, 0.5] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.17
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.28
# Epoch 6 training complete
# 6,0.33
# Epoch 7 training complete
# 7,0.33
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.39
# Epoch 10 training complete
# 10,0.45
# Epoch 11 training complete
# 11,0.43
# Epoch 12 training complete
# 12,0.5
# Epoch 13 training complete
# 13,0.5
# Epoch 14 training complete
# 14,0.52
# 0.586052417755127
# 0.13495984265931438
# 11
# [15, 10, 0.5] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6658909320831299
# 0.13132186191176184
# 25
# [15, 10, 1.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.26
# Epoch 1 training complete
# 1,0.28
# Epoch 2 training complete
# 2,0.52
# Epoch 3 training complete
# 3,0.67
# Epoch 4 training complete
# 4,0.57
# Epoch 5 training complete
# 5,0.66
# Epoch 6 training complete
# 6,0.63
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.7
# Epoch 9 training complete
# 9,0.65
# Epoch 10 training complete
# 10,0.68
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.67
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.67
# 0.356248140335083
# 0.07211335715459834
# 11
# [15, 10, 1.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.31
# Epoch 2 training complete
# 2,0.31
# Epoch 3 training complete
# 3,0.29
# Epoch 4 training complete
# 4,0.41
# Epoch 5 training complete
# 5,0.36
# Epoch 6 training complete
# 6,0.43
# Epoch 7 training complete
# 7,0.59
# Epoch 8 training complete
# 8,0.56
# Epoch 9 training complete
# 9,0.59
# Epoch 10 training complete
# 10,0.6
# Epoch 11 training complete
# 11,0.62
# Epoch 12 training complete
# 12,0.66
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.65
# 0.8477756977081299
# 0.15387385475669685
# 35
# [15, 10, 1.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.36
# Epoch 3 training complete
# 3,0.41
# Epoch 4 training complete
# 4,0.42
# Epoch 5 training complete
# 5,0.36
# Epoch 6 training complete
# 6,0.55
# Epoch 7 training complete
# 7,0.53
# Epoch 8 training complete
# 8,0.53
# Epoch 9 training complete
# 9,0.59
# Epoch 10 training complete
# 10,0.59
# Epoch 11 training complete
# 11,0.64
# Epoch 12 training complete
# 12,0.73
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.67
# 1.1875660419464111
# 0.10800796728078568
# 59
# [15, 10, 1.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.16
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.19
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.14
# 1.0362601280212402
# 0.13675756897283972
# 28
# [15, 10, 3.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.09
# Epoch 1 training complete
# 1,0.28
# Epoch 2 training complete
# 2,0.34
# Epoch 3 training complete
# 3,0.33
# Epoch 4 training complete
# 4,0.32
# Epoch 5 training complete
# 5,0.46
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.57
# Epoch 8 training complete
# 8,0.63
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.58
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.65
# Epoch 13 training complete
# 13,0.68
# Epoch 14 training complete
# 14,0.66
# 0.37746357917785645
# 0.06155419686350197
# 43
# [15, 10, 3.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.21
# Epoch 2 training complete
# 2,0.45
# Epoch 3 training complete
# 3,0.45
# Epoch 4 training complete
# 4,0.49
# Epoch 5 training complete
# 5,0.65
# Epoch 6 training complete
# 6,0.59
# Epoch 7 training complete
# 7,0.6
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.69
# Epoch 10 training complete
# 10,0.67
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.67
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.65
# 0.3993699550628662
# 0.10250861512725389
# 63
# [15, 10, 3.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.29
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.3
# Epoch 5 training complete
# 5,0.23
# Epoch 6 training complete
# 6,0.45
# Epoch 7 training complete
# 7,0.36
# Epoch 8 training complete
# 8,0.49
# Epoch 9 training complete
# 9,0.59
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.56
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.65
# Epoch 14 training complete
# 14,0.7
# 0.6471970081329346
# 0.14011332158353315
# 11
# [15, 10, 3.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.21
# Epoch 6 training complete
# 6,0.1
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.16
# Epoch 9 training complete
# 9,0.29
# Epoch 10 training complete
# 10,0.34
# Epoch 11 training complete
# 11,0.24
# Epoch 12 training complete
# 12,0.39
# Epoch 13 training complete
# 13,0.3
# Epoch 14 training complete
# 14,0.47
# 0.7211806774139404
# 0.13894341164873045
# 66
# [15, 10, 5.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.18
# Epoch 2 training complete
# 2,0.09
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.15
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.09
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.19
# Epoch 14 training complete
# 14,0.22
# 0.3879239559173584
# 0.2363630250680763
# 53
# [15, 10, 5.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.29
# Epoch 2 training complete
# 2,0.46
# Epoch 3 training complete
# 3,0.52
# Epoch 4 training complete
# 4,0.58
# Epoch 5 training complete
# 5,0.64
# Epoch 6 training complete
# 6,0.56
# Epoch 7 training complete
# 7,0.69
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.68
# Epoch 10 training complete
# 10,0.67
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.66
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.69
# 0.37894392013549805
# 0.18109797641016526
# 44
# [15, 10, 5.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.11
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.11
# Epoch 12 training complete
# 12,0.02
# Epoch 13 training complete
# 13,0.11
# Epoch 14 training complete
# 14,0.14
# 0.6179232597351074
# 0.1947350525532414
# 71
# [15, 10, 5.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.16
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.19
# Epoch 6 training complete
# 6,0.27
# Epoch 7 training complete
# 7,0.29
# Epoch 8 training complete
# 8,0.36
# Epoch 9 training complete
# 9,0.47
# Epoch 10 training complete
# 10,0.45
# Epoch 11 training complete
# 11,0.48
# Epoch 12 training complete
# 12,0.48
# Epoch 13 training complete
# 13,0.56
# Epoch 14 training complete
# 14,0.62
# 0.6695108413696289
# 0.23198197730406903
# 72
# [15, 20, 0.1] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.24
# Epoch 3 training complete
# 3,0.3
# Epoch 4 training complete
# 4,0.25
# Epoch 5 training complete
# 5,0.25
# Epoch 6 training complete
# 6,0.27
# Epoch 7 training complete
# 7,0.29
# Epoch 8 training complete
# 8,0.28
# Epoch 9 training complete
# 9,0.27
# Epoch 10 training complete
# 10,0.29
# Epoch 11 training complete
# 11,0.33
# Epoch 12 training complete
# 12,0.36
# Epoch 13 training complete
# 13,0.38
# Epoch 14 training complete
# 14,0.36
# 0.3628370761871338
# 0.11291649965113591
# 64
# [15, 20, 0.1] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.12
# Epoch 1 training complete
# 1,0.13
# Epoch 2 training complete
# 2,0.17
# Epoch 3 training complete
# 3,0.18
# Epoch 4 training complete
# 4,0.18
# Epoch 5 training complete
# 5,0.18
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.19
# Epoch 8 training complete
# 8,0.19
# Epoch 9 training complete
# 9,0.19
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.24
# Epoch 13 training complete
# 13,0.26
# Epoch 14 training complete
# 14,0.28
# 0.4047837257385254
# 0.1775883903639402
# 64
# [15, 20, 0.1] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.2
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.14
# 0.5973937511444092
# 0.12961333439037104
# 48
# [15, 20, 0.1] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.1
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.1
# Epoch 7 training complete
# 7,0.1
# Epoch 8 training complete
# 8,0.1
# Epoch 9 training complete
# 9,0.1
# Epoch 10 training complete
# 10,0.1
# Epoch 11 training complete
# 11,0.1
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.1
# Epoch 14 training complete
# 14,0.1
# 0.605966329574585
# 0.27163656618361837
# 25
# [15, 20, 0.5] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.44
# Epoch 2 training complete
# 2,0.31
# Epoch 3 training complete
# 3,0.49
# Epoch 4 training complete
# 4,0.61
# Epoch 5 training complete
# 5,0.59
# Epoch 6 training complete
# 6,0.63
# Epoch 7 training complete
# 7,0.57
# Epoch 8 training complete
# 8,0.6
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.65
# 0.3423755168914795
# 0.08254523736527301
# 11
# [15, 20, 0.5] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.18
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.28
# Epoch 5 training complete
# 5,0.33
# Epoch 6 training complete
# 6,0.32
# Epoch 7 training complete
# 7,0.36
# Epoch 8 training complete
# 8,0.35
# Epoch 9 training complete
# 9,0.34
# Epoch 10 training complete
# 10,0.34
# Epoch 11 training complete
# 11,0.37
# Epoch 12 training complete
# 12,0.37
# Epoch 13 training complete
# 13,0.39
# Epoch 14 training complete
# 14,0.39
# 0.40964245796203613
# 0.1395364487353463
# 12
# [15, 20, 0.5] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.23
# Epoch 6 training complete
# 6,0.17
# Epoch 7 training complete
# 7,0.25
# Epoch 8 training complete
# 8,0.18
# Epoch 9 training complete
# 9,0.5
# Epoch 10 training complete
# 10,0.26
# Epoch 11 training complete
# 11,0.37
# Epoch 12 training complete
# 12,0.41
# Epoch 13 training complete
# 13,0.43
# Epoch 14 training complete
# 14,0.44
# 1.253598928451538
# 0.13068520022133936
# 66
# [15, 20, 0.5] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 1.2853260040283203
# 0.13446993097970555
# 79
# [15, 20, 1.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.22
# Epoch 2 training complete
# 2,0.3
# Epoch 3 training complete
# 3,0.36
# Epoch 4 training complete
# 4,0.4
# Epoch 5 training complete
# 5,0.61
# Epoch 6 training complete
# 6,0.63
# Epoch 7 training complete
# 7,0.61
# Epoch 8 training complete
# 8,0.59
# Epoch 9 training complete
# 9,0.6
# Epoch 10 training complete
# 10,0.67
# Epoch 11 training complete
# 11,0.64
# Epoch 12 training complete
# 12,0.68
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.68
# 0.6808030605316162
# 0.09374841777438721
# 11
# [15, 20, 1.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.33
# Epoch 2 training complete
# 2,0.31
# Epoch 3 training complete
# 3,0.35
# Epoch 4 training complete
# 4,0.37
# Epoch 5 training complete
# 5,0.43
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.45
# Epoch 8 training complete
# 8,0.48
# Epoch 9 training complete
# 9,0.49
# Epoch 10 training complete
# 10,0.46
# Epoch 11 training complete
# 11,0.46
# Epoch 12 training complete
# 12,0.45
# Epoch 13 training complete
# 13,0.47
# Epoch 14 training complete
# 14,0.51
# 0.38176822662353516
# 0.15000937920333152
# 63
# [15, 20, 1.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.21
# Epoch 4 training complete
# 4,0.24
# Epoch 5 training complete
# 5,0.15
# Epoch 6 training complete
# 6,0.19
# Epoch 7 training complete
# 7,0.38
# Epoch 8 training complete
# 8,0.28
# Epoch 9 training complete
# 9,0.46
# Epoch 10 training complete
# 10,0.35
# Epoch 11 training complete
# 11,0.45
# Epoch 12 training complete
# 12,0.54
# Epoch 13 training complete
# 13,0.52
# Epoch 14 training complete
# 14,0.47
# 0.5932517051696777
# 0.12910933559142862
# 82
# [15, 20, 1.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6499240398406982
# 0.13547760098079262
# 25
# [15, 20, 3.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.27
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.32
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.39
# Epoch 7 training complete
# 7,0.44
# Epoch 8 training complete
# 8,0.48
# Epoch 9 training complete
# 9,0.55
# Epoch 10 training complete
# 10,0.5
# Epoch 11 training complete
# 11,0.46
# Epoch 12 training complete
# 12,0.45
# Epoch 13 training complete
# 13,0.52
# Epoch 14 training complete
# 14,0.47
# 0.3530712127685547
# 0.08868337661636064
# 54
# [15, 20, 3.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.24
# Epoch 2 training complete
# 2,0.24
# Epoch 3 training complete
# 3,0.45
# Epoch 4 training complete
# 4,0.45
# Epoch 5 training complete
# 5,0.4
# Epoch 6 training complete
# 6,0.51
# Epoch 7 training complete
# 7,0.59
# Epoch 8 training complete
# 8,0.64
# Epoch 9 training complete
# 9,0.59
# Epoch 10 training complete
# 10,0.67
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.66
# Epoch 13 training complete
# 13,0.65
# Epoch 14 training complete
# 14,0.65
# 0.494473934173584
# 0.1613669106002321
# 63
# [15, 20, 3.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.19
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.25
# Epoch 7 training complete
# 7,0.25
# Epoch 8 training complete
# 8,0.19
# Epoch 9 training complete
# 9,0.33
# Epoch 10 training complete
# 10,0.51
# Epoch 11 training complete
# 11,0.45
# Epoch 12 training complete
# 12,0.49
# Epoch 13 training complete
# 13,0.41
# Epoch 14 training complete
# 14,0.39
# 0.5786561965942383
# 0.14277721350597739
# 54
# [15, 20, 3.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.2
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.13
# Epoch 5 training complete
# 5,0.18
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.16
# Epoch 10 training complete
# 10,0.21
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.13
# Epoch 14 training complete
# 14,0.26
# 0.6071896553039551
# 0.1543654549984675
# 21
# [15, 20, 5.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.07
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.11
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.08
# Epoch 13 training complete
# 13,0.11
# Epoch 14 training complete
# 14,0.14
# 0.3844466209411621
# 0.40780219821365915
# 59
# [15, 20, 5.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.3
# Epoch 2 training complete
# 2,0.3
# Epoch 3 training complete
# 3,0.45
# Epoch 4 training complete
# 4,0.55
# Epoch 5 training complete
# 5,0.6
# Epoch 6 training complete
# 6,0.57
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.66
# Epoch 9 training complete
# 9,0.67
# Epoch 10 training complete
# 10,0.67
# Epoch 11 training complete
# 11,0.7
# Epoch 12 training complete
# 12,0.68
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.69
# 0.4124166965484619
# 0.16471294435003048
# 47
# [15, 20, 5.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.11
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.1
# 0.6615097522735596
# 0.19176519085880134
# 40
# [15, 20, 5.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.13
# Epoch 5 training complete
# 5,0.13
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.2
# Epoch 8 training complete
# 8,0.2
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.29
# Epoch 11 training complete
# 11,0.34
# Epoch 12 training complete
# 12,0.42
# Epoch 13 training complete
# 13,0.35
# Epoch 14 training complete
# 14,0.51
# 0.643965482711792
# 0.14737515992892647
# 82
# [15, 100, 0.1] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.12
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.11
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.12
# Epoch 9 training complete
# 9,0.17
# Epoch 10 training complete
# 10,0.17
# Epoch 11 training complete
# 11,0.16
# Epoch 12 training complete
# 12,0.16
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.15
# 0.40249013900756836
# 0.15258705690347948
# 79
# [15, 100, 0.1] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.07
# Epoch 8 training complete
# 8,0.07
# Epoch 9 training complete
# 9,0.06
# Epoch 10 training complete
# 10,0.07
# Epoch 11 training complete
# 11,0.07
# Epoch 12 training complete
# 12,0.08
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.07
# 0.39794039726257324
# 0.46514032665803257
# 51
# [15, 100, 0.1] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.16
# Epoch 9 training complete
# 9,0.11
# Epoch 10 training complete
# 10,0.11
# Epoch 11 training complete
# 11,0.09
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6017429828643799
# 0.17235683409856398
# 93
# [15, 100, 0.1] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 1.4008057117462158
# 0.8805709376741285
# 15
# [15, 100, 0.5] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.17
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.26
# Epoch 4 training complete
# 4,0.35
# Epoch 5 training complete
# 5,0.37
# Epoch 6 training complete
# 6,0.42
# Epoch 7 training complete
# 7,0.45
# Epoch 8 training complete
# 8,0.51
# Epoch 9 training complete
# 9,0.5
# Epoch 10 training complete
# 10,0.52
# Epoch 11 training complete
# 11,0.51
# Epoch 12 training complete
# 12,0.51
# Epoch 13 training complete
# 13,0.51
# Epoch 14 training complete
# 14,0.51
# 0.7833068370819092
# 0.1232113372550655
# 82
# [15, 100, 0.5] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.06
# Epoch 1 training complete
# 1,0.06
# Epoch 2 training complete
# 2,0.06
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.1
# Epoch 5 training complete
# 5,0.13
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.2
# Epoch 8 training complete
# 8,0.23
# Epoch 9 training complete
# 9,0.23
# Epoch 10 training complete
# 10,0.23
# Epoch 11 training complete
# 11,0.23
# Epoch 12 training complete
# 12,0.23
# Epoch 13 training complete
# 13,0.23
# Epoch 14 training complete
# 14,0.23
# 0.7505583763122559
# 0.13912355175826688
# 93
# [15, 100, 0.5] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.5795824527740479
# 0.1345525201775989
# 68
# [15, 100, 0.5] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.11
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.11
# Epoch 10 training complete
# 10,0.11
# Epoch 11 training complete
# 11,0.11
# Epoch 12 training complete
# 12,0.11
# Epoch 13 training complete
# 13,0.11
# Epoch 14 training complete
# 14,0.11
# 0.6041960716247559
# 0.2147500123703833
# 95
# [15, 100, 1.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.4
# Epoch 2 training complete
# 2,0.34
# Epoch 3 training complete
# 3,0.35
# Epoch 4 training complete
# 4,0.41
# Epoch 5 training complete
# 5,0.44
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.5
# Epoch 8 training complete
# 8,0.54
# Epoch 9 training complete
# 9,0.55
# Epoch 10 training complete
# 10,0.58
# Epoch 11 training complete
# 11,0.58
# Epoch 12 training complete
# 12,0.58
# Epoch 13 training complete
# 13,0.6
# Epoch 14 training complete
# 14,0.61
# 0.3667888641357422
# 0.11864979407915892
# 11
# [15, 100, 1.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.15
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.13
# Epoch 7 training complete
# 7,0.21
# Epoch 8 training complete
# 8,0.25
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.25
# Epoch 11 training complete
# 11,0.23
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.24
# Epoch 14 training complete
# 14,0.26
# 0.37888026237487793
# 0.13753145721132393
# 48
# [15, 100, 1.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.15
# Epoch 8 training complete
# 8,0.17
# Epoch 9 training complete
# 9,0.19
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.21
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.21
# Epoch 14 training complete
# 14,0.21
# 0.5976195335388184
# 0.13139988531609179
# 9
# [15, 100, 1.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.15
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.13
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.15
# Epoch 9 training complete
# 9,0.18
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.21
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.21
# Epoch 14 training complete
# 14,0.21
# 0.625511884689331
# 0.14505124935595273
# 79
# [15, 100, 3.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.1
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.25
# Epoch 7 training complete
# 7,0.28
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.38
# Epoch 10 training complete
# 10,0.33
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.39
# Epoch 14 training complete
# 14,0.51
# 0.35396265983581543
# 0.14993024863184268
# 24
# [15, 100, 3.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.16
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.22
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.22
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.22
# 0.43337154388427734
# 0.1428458088699878
# 68
# [15, 100, 3.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6217944622039795
# 0.1385853520216344
# 86
# [15, 100, 3.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.16
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.21
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.17
# Epoch 8 training complete
# 8,0.17
# Epoch 9 training complete
# 9,0.16
# Epoch 10 training complete
# 10,0.16
# Epoch 11 training complete
# 11,0.16
# Epoch 12 training complete
# 12,0.16
# Epoch 13 training complete
# 13,0.17
# Epoch 14 training complete
# 14,0.17
# 0.5957076549530029
# 0.13362931504979622
# 87
# [15, 100, 5.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.22
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.27
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.24
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.26
# 0.3947930335998535
# 0.11067346574203414
# 53
# [15, 100, 5.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.19
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.26
# Epoch 6 training complete
# 6,0.3
# Epoch 7 training complete
# 7,0.32
# Epoch 8 training complete
# 8,0.37
# Epoch 9 training complete
# 9,0.39
# Epoch 10 training complete
# 10,0.41
# Epoch 11 training complete
# 11,0.42
# Epoch 12 training complete
# 12,0.42
# Epoch 13 training complete
# 13,0.42
# Epoch 14 training complete
# 14,0.43
# 0.3838174343109131
# 0.1527090670138104
# 34
# [15, 100, 5.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.12
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.5990288257598877
# 0.13923733777441413
# 40
# [15, 100, 5.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.15
# 0.6735837459564209
# 0.13565863283270674
# 71
# [30, 5, 0.1] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.27
# Epoch 1 training complete
# 1,0.45
# Epoch 2 training complete
# 2,0.42
# Epoch 3 training complete
# 3,0.49
# Epoch 4 training complete
# 4,0.57
# Epoch 5 training complete
# 5,0.63
# Epoch 6 training complete
# 6,0.65
# Epoch 7 training complete
# 7,0.62
# ...
# 51,0.22
# Epoch 52 training complete
# 52,0.22
# Epoch 53 training complete
# 53,0.22
# Epoch 54 training complete
# 54,0.22
# Epoch 55 training complete
# 55,0.22
# Epoch 56 training complete
# 56,0.22
# Epoch 57 training complete
# 57,0.22
# Epoch 58 training complete
# 58,0.22
# Epoch 59 training complete
# 59,0.22
# Epoch 60 training complete
# 60,0.22
# Epoch 61 training complete
# 61,0.22
# Epoch 62 training complete
# 62,0.22
# Epoch 63 training complete
# 63,0.22
# Epoch 64 training complete
# 64,0.22
# Epoch 65 training complete
# 65,0.22
# Epoch 66 training complete
# 66,0.22
# Epoch 67 training complete
# 67,0.22
# Epoch 68 training complete
# 68,0.22
# Epoch 69 training complete
# 69,0.22
# Epoch 70 training complete
# 70,0.22
# Epoch 71 training complete
# 71,0.22
# Epoch 72 training complete
# 72,0.23
# Epoch 73 training complete
# 73,0.23
# Epoch 74 training complete
# 74,0.23
# Epoch 75 training complete
# 75,0.23
# Epoch 76 training complete
# 76,0.23
# Epoch 77 training complete
# 77,0.23
# Epoch 78 training complete
# 78,0.23
# Epoch 79 training complete
# 79,0.23
# Epoch 80 training complete
# 80,0.23
# Epoch 81 training complete
# 81,0.23
# Epoch 82 training complete
# 82,0.23
# Epoch 83 training complete
# 83,0.23
# Epoch 84 training complete
# 84,0.23
# Epoch 85 training complete
# 85,0.24
# Epoch 86 training complete
# 86,0.24
# Epoch 87 training complete
# 87,0.25
# Epoch 88 training complete
# 88,0.25
# Epoch 89 training complete
# 89,0.26
# Epoch 90 training complete
# 90,0.26
# Epoch 91 training complete
# 91,0.26
# Epoch 92 training complete
# 92,0.26
# Epoch 93 training complete
# 93,0.26
# Epoch 94 training complete
# 94,0.26
# Epoch 95 training complete
# 95,0.27
# Epoch 96 training complete
# 96,0.28
# Epoch 97 training complete
# 97,0.28
# Epoch 98 training complete
# 98,0.29
# Epoch 99 training complete
# 99,0.3
# 5.762182235717773
# 0.15918422144626615
# 82
# [100, 100, 5.0] single hidden layer plus cross-entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.25
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.21
# Epoch 11 training complete
# 11,0.15
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.21
# Epoch 14 training complete
# 14,0.2
# Epoch 15 training complete
# 15,0.22
# Epoch 16 training complete
# 16,0.25
# Epoch 17 training complete
# 17,0.22
# Epoch 18 training complete
# 18,0.24
# Epoch 19 training complete
# 19,0.23
# Epoch 20 training complete
# 20,0.35
# Epoch 21 training complete
# 21,0.37
# Epoch 22 training complete
# 22,0.2
# Epoch 23 training complete
# 23,0.22
# Epoch 24 training complete
# 24,0.34
# Epoch 25 training complete
# 25,0.26
# Epoch 26 training complete
# 26,0.21
# Epoch 27 training complete
# 27,0.28
# Epoch 28 training complete
# 28,0.44
# Epoch 29 training complete
# 29,0.43
# Epoch 30 training complete
# 30,0.38
# Epoch 31 training complete
# 31,0.37
# Epoch 32 training complete
# 32,0.35
# Epoch 33 training complete
# 33,0.18
# Epoch 34 training complete
# 34,0.32
# Epoch 35 training complete
# 35,0.36
# Epoch 36 training complete
# 36,0.37
# Epoch 37 training complete
# 37,0.38
# Epoch 38 training complete
# 38,0.4
# Epoch 39 training complete
# 39,0.41
# Epoch 40 training complete
# 40,0.41
# Epoch 41 training complete
# 41,0.41
# Epoch 42 training complete
# 42,0.41
# Epoch 43 training complete
# 43,0.41
# Epoch 44 training complete
# 44,0.42
# Epoch 45 training complete
# 45,0.41
# Epoch 46 training complete
# 46,0.41
# Epoch 47 training complete
# 47,0.41
# Epoch 48 training complete
# 48,0.42
# Epoch 49 training complete
# 49,0.41
# Epoch 50 training complete
# 50,0.41
# Epoch 51 training complete
# 51,0.43
# Epoch 52 training complete
# 52,0.42
# Epoch 53 training complete
# 53,0.44
# Epoch 54 training complete
# 54,0.44
# Epoch 55 training complete
# 55,0.43
# Epoch 56 training complete
# 56,0.44
# Epoch 57 training complete
# 57,0.43
# Epoch 58 training complete
# 58,0.43
# Epoch 59 training complete
# 59,0.45
# Epoch 60 training complete
# 60,0.44
# Epoch 61 training complete
# 61,0.46
# Epoch 62 training complete
# 62,0.45
# Epoch 63 training complete
# 63,0.46
# Epoch 64 training complete
# 64,0.45
# Epoch 65 training complete
# 65,0.46
# Epoch 66 training complete
# 66,0.46
# Epoch 67 training complete
# 67,0.46
# Epoch 68 training complete
# 68,0.46
# Epoch 69 training complete
# 69,0.46
# Epoch 70 training complete
# 70,0.47
# Epoch 71 training complete
# 71,0.44
# Epoch 72 training complete
# 72,0.45
# Epoch 73 training complete
# 73,0.46
# Epoch 74 training complete
# 74,0.48
# Epoch 75 training complete
# 75,0.46
# Epoch 76 training complete
# 76,0.5
# Epoch 77 training complete
# 77,0.51
# Epoch 78 training complete
# 78,0.52
# Epoch 79 training complete
# 79,0.51
# Epoch 80 training complete
# 80,0.49
# Epoch 81 training complete
# 81,0.51
# Epoch 82 training complete
# 82,0.52
# Epoch 83 training complete
# 83,0.51
# Epoch 84 training complete
# 84,0.52
# Epoch 85 training complete
# 85,0.51
# Epoch 86 training complete
# 86,0.5
# Epoch 87 training complete
# 87,0.51
# Epoch 88 training complete
# 88,0.51
# Epoch 89 training complete
# 89,0.51
# Epoch 90 training complete
# 90,0.5
# Epoch 91 training complete
# 91,0.51
# Epoch 92 training complete
# 92,0.5
# Epoch 93 training complete
# 93,0.51
# Epoch 94 training complete
# 94,0.49
# Epoch 95 training complete
# 95,0.51
# Epoch 96 training complete
# 96,0.51
# Epoch 97 training complete
# 97,0.49
# Epoch 98 training complete
# 98,0.51
# Epoch 99 training complete
# 99,0.51
# 2.815676689147949
# 0.08397410830022894
# 23
# [100, 100, 5.0] single hidden layer plus quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.24
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.2
# Epoch 6 training complete
# 6,0.2
# Epoch 7 training complete
# 7,0.2
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.21
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.21
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.21
# Epoch 14 training complete
# 14,0.21
# Epoch 15 training complete
# 15,0.21
# Epoch 16 training complete
# 16,0.21
# Epoch 17 training complete
# 17,0.21
# Epoch 18 training complete
# 18,0.21
# Epoch 19 training complete
# 19,0.22
# Epoch 20 training complete
# 20,0.22
# Epoch 21 training complete
# 21,0.22
# Epoch 22 training complete
# 22,0.22
# Epoch 23 training complete
# 23,0.23
# Epoch 24 training complete
# 24,0.23
# Epoch 25 training complete
# 25,0.23
# Epoch 26 training complete
# 26,0.23
# Epoch 27 training complete
# 27,0.24
# Epoch 28 training complete
# 28,0.25
# Epoch 29 training complete
# 29,0.26
# Epoch 30 training complete
# 30,0.26
# Epoch 31 training complete
# 31,0.27
# Epoch 32 training complete
# 32,0.31
# Epoch 33 training complete
# 33,0.31
# Epoch 34 training complete
# 34,0.33
# Epoch 35 training complete
# 35,0.34
# Epoch 36 training complete
# 36,0.36
# Epoch 37 training complete
# 37,0.36
# Epoch 38 training complete
# 38,0.38
# Epoch 39 training complete
# 39,0.4
# Epoch 40 training complete
# 40,0.4
# Epoch 41 training complete
# 41,0.41
# Epoch 42 training complete
# 42,0.42
# Epoch 43 training complete
# 43,0.42
# Epoch 44 training complete
# 44,0.43
# Epoch 45 training complete
# 45,0.43
# Epoch 46 training complete
# 46,0.44
# Epoch 47 training complete
# 47,0.44
# Epoch 48 training complete
# 48,0.44
# Epoch 49 training complete
# 49,0.44
# Epoch 50 training complete
# 50,0.44
# Epoch 51 training complete
# 51,0.44
# Epoch 52 training complete
# 52,0.44
# Epoch 53 training complete
# 53,0.44
# Epoch 54 training complete
# 54,0.44
# Epoch 55 training complete
# 55,0.44
# Epoch 56 training complete
# 56,0.46
# Epoch 57 training complete
# 57,0.47
# Epoch 58 training complete
# 58,0.48
# Epoch 59 training complete
# 59,0.48
# Epoch 60 training complete
# 60,0.48
# Epoch 61 training complete
# 61,0.49
# Epoch 62 training complete
# 62,0.49
# Epoch 63 training complete
# 63,0.5
# Epoch 64 training complete
# 64,0.51
# Epoch 65 training complete
# 65,0.51
# Epoch 66 training complete
# 66,0.53
# Epoch 67 training complete
# 67,0.54
# Epoch 68 training complete
# 68,0.54
# Epoch 69 training complete
# 69,0.54
# Epoch 70 training complete
# 70,0.54
# Epoch 71 training complete
# 71,0.54
# Epoch 72 training complete
# 72,0.55
# Epoch 73 training complete
# 73,0.55
# Epoch 74 training complete
# 74,0.57
# Epoch 75 training complete
# 75,0.57
# Epoch 76 training complete
# 76,0.58
# Epoch 77 training complete
# 77,0.59
# Epoch 78 training complete
# 78,0.59
# Epoch 79 training complete
# 79,0.6
# Epoch 80 training complete
# 80,0.6
# Epoch 81 training complete
# 81,0.6
# Epoch 82 training complete
# 82,0.6
# Epoch 83 training complete
# 83,0.6
# Epoch 84 training complete
# 84,0.6
# Epoch 85 training complete
# 85,0.6
# Epoch 86 training complete
# 86,0.61
# Epoch 87 training complete
# 87,0.64
# Epoch 88 training complete
# 88,0.63
# Epoch 89 training complete
# 89,0.63
# Epoch 90 training complete
# 90,0.62
# Epoch 91 training complete
# 91,0.62
# Epoch 92 training complete
# 92,0.62
# Epoch 93 training complete
# 93,0.63
# Epoch 94 training complete
# 94,0.63
# Epoch 95 training complete
# 95,0.63
# Epoch 96 training complete
# 96,0.63
# Epoch 97 training complete
# 97,0.63
# Epoch 98 training complete
# 98,0.63
# Epoch 99 training complete
# 99,0.63
# 3.0801987648010254
# 0.11372623769446
# 23
# [100, 100, 5.0] dual hidden layers plus cross-entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# Epoch 15 training complete
# 15,0.14
# Epoch 16 training complete
# 16,0.14
# Epoch 17 training complete
# 17,0.14
# Epoch 18 training complete
# 18,0.14
# Epoch 19 training complete
# 19,0.14
# Epoch 20 training complete
# 20,0.14
# Epoch 21 training complete
# 21,0.14
# Epoch 22 training complete
# 22,0.14
# Epoch 23 training complete
# 23,0.14
# Epoch 24 training complete
# 24,0.14
# Epoch 25 training complete
# 25,0.14
# Epoch 26 training complete
# 26,0.14
# Epoch 27 training complete
# 27,0.14
# Epoch 28 training complete
# 28,0.14
# Epoch 29 training complete
# 29,0.14
# Epoch 30 training complete
# 30,0.14
# Epoch 31 training complete
# 31,0.14
# Epoch 32 training complete
# 32,0.14
# Epoch 33 training complete
# 33,0.14
# Epoch 34 training complete
# 34,0.14
# Epoch 35 training complete
# 35,0.14
# Epoch 36 training complete
# 36,0.14
# Epoch 37 training complete
# 37,0.14
# Epoch 38 training complete
# 38,0.14
# Epoch 39 training complete
# 39,0.14
# Epoch 40 training complete
# 40,0.14
# Epoch 41 training complete
# 41,0.14
# Epoch 42 training complete
# 42,0.14
# Epoch 43 training complete
# 43,0.14
# Epoch 44 training complete
# 44,0.14
# Epoch 45 training complete
# 45,0.14
# Epoch 46 training complete
# 46,0.14
# Epoch 47 training complete
# 47,0.14
# Epoch 48 training complete
# 48,0.14
# Epoch 49 training complete
# 49,0.14
# Epoch 50 training complete
# 50,0.14
# Epoch 51 training complete
# 51,0.14
# Epoch 52 training complete
# 52,0.14
# Epoch 53 training complete
# 53,0.14
# Epoch 54 training complete
# 54,0.14
# Epoch 55 training complete
# 55,0.14
# Epoch 56 training complete
# 56,0.14
# Epoch 57 training complete
# 57,0.14
# Epoch 58 training complete
# 58,0.14
# Epoch 59 training complete
# 59,0.14
# Epoch 60 training complete
# 60,0.14
# Epoch 61 training complete
# 61,0.14
# Epoch 62 training complete
# 62,0.14
# Epoch 63 training complete
# 63,0.14
# Epoch 64 training complete
# 64,0.14
# Epoch 65 training complete
# 65,0.14
# Epoch 66 training complete
# 66,0.14
# Epoch 67 training complete
# 67,0.14
# Epoch 68 training complete
# 68,0.14
# Epoch 69 training complete
# 69,0.14
# Epoch 70 training complete
# 70,0.14
# Epoch 71 training complete
# 71,0.14
# Epoch 72 training complete
# 72,0.14
# Epoch 73 training complete
# 73,0.14
# Epoch 74 training complete
# 74,0.14
# Epoch 75 training complete
# 75,0.14
# Epoch 76 training complete
# 76,0.14
# Epoch 77 training complete
# 77,0.14
# Epoch 78 training complete
# 78,0.14
# Epoch 79 training complete
# 79,0.14
# Epoch 80 training complete
# 80,0.14
# Epoch 81 training complete
# 81,0.14
# Epoch 82 training complete
# 82,0.14
# Epoch 83 training complete
# 83,0.14
# Epoch 84 training complete
# 84,0.14
# Epoch 85 training complete
# 85,0.14
# Epoch 86 training complete
# 86,0.14
# Epoch 87 training complete
# 87,0.14
# Epoch 88 training complete
# 88,0.14
# Epoch 89 training complete
# 89,0.14
# Epoch 90 training complete
# 90,0.14
# Epoch 91 training complete
# 91,0.14
# Epoch 92 training complete
# 92,0.14
# Epoch 93 training complete
# 93,0.14
# Epoch 94 training complete
# 94,0.14
# Epoch 95 training complete
# 95,0.14
# Epoch 96 training complete
# 96,0.14
# Epoch 97 training complete
# 97,0.14
# Epoch 98 training complete
# 98,0.14
# Epoch 99 training complete
# 99,0.14
# 6.542612552642822
# 0.13981222777734126
# 81
# [100, 100, 5.0] dual hidden layers plus quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.17
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.21
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.22
# Epoch 15 training complete
# 15,0.22
# Epoch 16 training complete
# 16,0.22
# Epoch 17 training complete
# 17,0.22
# Epoch 18 training complete
# 18,0.22
# Epoch 19 training complete
# 19,0.22
# Epoch 20 training complete
# 20,0.22
# Epoch 21 training complete
# 21,0.22
# Epoch 22 training complete
# 22,0.22
# Epoch 23 training complete
# 23,0.22
# Epoch 24 training complete
# 24,0.22
# Epoch 25 training complete
# 25,0.22
# Epoch 26 training complete
# 26,0.22
# Epoch 27 training complete
# 27,0.22
# Epoch 28 training complete
# 28,0.22
# Epoch 29 training complete
# 29,0.22
# Epoch 30 training complete
# 30,0.22
# Epoch 31 training complete
# 31,0.22
# Epoch 32 training complete
# 32,0.22
# Epoch 33 training complete
# 33,0.22
# Epoch 34 training complete
# 34,0.22
# Epoch 35 training complete
# 35,0.22
# Epoch 36 training complete
# 36,0.22
# Epoch 37 training complete
# 37,0.22
# Epoch 38 training complete
# 38,0.22
# Epoch 39 training complete
# 39,0.22
# Epoch 40 training complete
# 40,0.22
# Epoch 41 training complete
# 41,0.22
# Epoch 42 training complete
# 42,0.23
# Epoch 43 training complete
# 43,0.23
# Epoch 44 training complete
# 44,0.23
# Epoch 45 training complete
# 45,0.23
# Epoch 46 training complete
# 46,0.24
# Epoch 47 training complete
# 47,0.24
# Epoch 48 training complete
# 48,0.24
# Epoch 49 training complete
# 49,0.24
# Epoch 50 training complete
# 50,0.24
# Epoch 51 training complete
# 51,0.24
# Epoch 52 training complete
# 52,0.25
# Epoch 53 training complete
# 53,0.25
# Epoch 54 training complete
# 54,0.25
# Epoch 55 training complete
# 55,0.26
# Epoch 56 training complete
# 56,0.27
# Epoch 57 training complete
# 57,0.27
# Epoch 58 training complete
# 58,0.27
# Epoch 59 training complete
# 59,0.27
# Epoch 60 training complete
# 60,0.28
# Epoch 61 training complete
# 61,0.28
# Epoch 62 training complete
# 62,0.28
# Epoch 63 training complete
# 63,0.28
# Epoch 64 training complete
# 64,0.28
# Epoch 65 training complete
# 65,0.29
# Epoch 66 training complete
# 66,0.29
# Epoch 67 training complete
# 67,0.3
# Epoch 68 training complete
# 68,0.3
# Epoch 69 training complete
# 69,0.31
# Epoch 70 training complete
# 70,0.31
# Epoch 71 training complete
# 71,0.31
# Epoch 72 training complete
# 72,0.31
# Epoch 73 training complete
# 73,0.32
# Epoch 74 training complete
# 74,0.32
# Epoch 75 training complete
# 75,0.33
# Epoch 76 training complete
# 76,0.33
# Epoch 77 training complete
# 77,0.33
# Epoch 78 training complete
# 78,0.33
# Epoch 79 training complete
# 79,0.33
# Epoch 80 training complete
# 80,0.33
# Epoch 81 training complete
# 81,0.33
# Epoch 82 training complete
# 82,0.34
# Epoch 83 training complete
# 83,0.34
# Epoch 84 training complete
# 84,0.35
# Epoch 85 training complete
# 85,0.35
# Epoch 86 training complete
# 86,0.35
# Epoch 87 training complete
# 87,0.35
# Epoch 88 training complete
# 88,0.35
# Epoch 89 training complete
# 89,0.36
# Epoch 90 training complete
# 90,0.36
# Epoch 91 training complete
# 91,0.36
# Epoch 92 training complete
# 92,0.36
# Epoch 93 training complete
# 93,0.36
# Epoch 94 training complete
# 94,0.36
# Epoch 95 training complete
# 95,0.36
# Epoch 96 training complete
# 96,0.37
# Epoch 97 training complete
# 97,0.37
# Epoch 98 training complete
# 98,0.37
# Epoch 99 training complete
# 99,0.37
# 4.897048473358154
# 0.145321633208139
# 59

# %%
import matplotlib.pyplot as plt

# pre-process our really janked up data ... first the training_times
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []
for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
    training_timesSingle.append(tt1)
    training_timesSingle.append(tt2)
for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
    training_timesDouble.append(tt1)
    training_timesDouble.append(tt2)

# and now the accuracies...
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []
for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
    accuraciesSingle.append(acc1[1][-1])
    accuraciesSingle.append(acc2[1][-1])
for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
    accuraciesDouble.append(acc1[1][-1])
    accuraciesDouble.append(acc2[1][-1])

# and now the labels
labelsSingle = []
labelsDouble = []
for config in configs:
    labelsSingle.append(f"{config}-cross-784-15-10")
    labelsSingle.append(f"{config}-quad-784-15-10")
    labelsDouble.append(f"{config}-cross-784-30-15-10")
    labelsDouble.append(f"{config}-quad-784-30-15-10")

fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsSingle, accuraciesSingle)
plt.show()
fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsDouble, training_timesDouble)
plt.show()

# %%
# extract the "results" (training times and accuracies) for all configs where the # epochs is 30, the batch size is 10, the cost function is quadratic and the learning rate is variable
label_learningrate = []
tt_learningrate = []
acc_learningrate = []
for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i])
    tt_learningrate.append(training_timesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)
    acc_learningrate.append(accuraciesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)

print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
# Out:
# ['[30, 10, 0.1]-cross-784-15-10', '[30, 10, 0.5]-cross-784-15-10', '[30, 10, 1.0]-cross-784-15-10', '[30, 10, 3.0]-cross-784-15-10', '[30, 10, 5.0]-cross-784-15-10']
# [1.1476881504058838, 0.7570929527282715, 1.3585286140441895, 0.7560012340545654, 0.8356010913848877]
# [69, 68, 71, 67, 23]
# <function matplotlib.pyplot.show(*args, **kw)>
